# %%
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing
import csv

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = '7H0tnWTrwJUaWBGY5RCub8LEW'
CONSUMER_SECRET = 'HxuA9wyMy48WqSrFYcdeB9fMfibPvPuMVrKSILDQ2q9tR0dsRY'

# Access:
ACCESS_TOKEN  = '902769774022840320-Tg7ZYxxDVrAwKno9ctuMie8bNxv5nRH'
ACCESS_SECRET = 'a8DNJVG9B2y2G7B6fxUPcl4zzbLjsalDDhP2DAGgyRlV1'

# We import our access keys:
from credentials import *    # This will allow us to use the keys as variables

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# We create an extractor object:
extractor = twitter_setup()
screen_name="ICC"
# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name, count=200)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("100 recent tweets:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
   
    # We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])


# We display the first 10 elements of the dataframe:
#display(data.head(10))


        
# Internal methods of a single tweet object:
#print(dir(tweets[0]))

# We print info from the first tweet:
#print(tweets[0].id)
#print(tweets[0].created_at)
#print(tweets[0].source)
#print(tweets[0].favorite_count)
#print(tweets[0].retweet_count)
#print(tweets[0].geo)
#print(tweets[0].coordinates)
#print(tweets[0].entities)

# We add relevant data:
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# Display of first 10 elements from dataframe:
##display(data.head(10))

# We extract the mean of lenghts:
mean = np.mean(data['len'])

print("The lenght's average in tweets: {}".format(mean))

# We extract the tweet with more FAVs and more RTs:

fav_max = np.max(data['Likes'])
rt_max  = np.max(data['RTs'])

fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

# Max FAVs:
print("The tweet with more likes is: \n{}".format(data['Tweets'][fav]))
print("Number of likes: {}".format(fav_max))
print("{} characters.\n".format(data['len'][fav]))

# Max RTs:
print("The tweet with more retweets is: \n{}".format(data['Tweets'][rt]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(data['len'][rt]))

# We create time series for data:

tlen = pd.Series(data=data['len'].values, index=data['Date'])
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

# Lengths along time:
tlen.plot(figsize=(16,4), color='r');

# Likes vs retweets visualization:
tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True);

# We obtain all possible sources:
sources = []
for source in data['Source']:
    if source not in sources:
        sources.append(source)

# We print sources list:
print("Creation of content sources:")
for source in sources:
    print("* {}".format(source))
# We create a numpy vector mapped to labels:
percent = np.zeros(len(sources))

for source in data['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

percent /= 100



from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1
    
    # We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the updated dataframe with the new column:
display(data.head(100))

#Create a CSV file and store the tweet details in it.
output = [[tweet.id,tweet.created_at,tweet.text.encode("utf-8"),len(tweet.text),tweet.source,tweet.favorite_count,tweet.retweet_count] for tweet in tweets]
with open(r'C:\Users\Ayushi\Desktop\analyze_tweets.csv','w') as file:
        writer = csv.writer(file)
        writer.writerow(["id","created_at","text","length","source","favorites","RT"])
        writer.writerows(output)
print("--------------------Data added to the csv file--------------------------")

# We construct lists with classified tweets:

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# We print percentages:

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Pie chart:
pie_chart = pd.Series(percent, index=sources, name='Sources')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6));
# Out:
# Number of tweets extracted: 200.
#
# 100 recent tweets:
#
# India captain @M_Raj03 on the rapid development of women's cricket across the world 🙌
#
# https://t.co/Dvzhg2YexL https://t.co/vSV5AnaUuf
#
# Happy birthday to Nepal's Shakti Gauchan!
#
# Watch him take a brilliant 3/9 against Hong Kong at #WT20 in 2014! https://t.co/3V9gl4laPF
#
# “KL looked like a million dollars, and well, Chris is Chris”
#
# @lionsdenkxip captain @ashwinravi99 can't get enough… https://t.co/dMjAZxINfW
#
# 6,792 international runs
# Joint fastest to 1,000 ODI runs
# ICC Cricketer of the Year 2011
#
# Happy birthday to former E… https://t.co/tXNe2Kwtlg
#
# "The team is inexperienced, but we are trying to give it confidence.”
#
# Sarfraz Ahmed gung-ho about Pakistan's chanc… https://t.co/2laKU27NG9
#
# RT @ICCAcademy: The #ICCAcademy welcomed @CricketBermuda on Saturday for what was the beginning of 3 days of training and practice matches…
#
# Happy 52nd birthday to ICC Elite Umpire Sundaram Ravi! https://t.co/aJviZZTVfU
#
# AB IS BACK!
#
# "Some of the nights you see the ball well" - and what a night it was!
#
# @ABdeVilliers17's thoughts on… https://t.co/p5BItuJzUo
# "There's nothing more certain in life than change. Having a new captain is a good idea and it maybe would be diffic… https://t.co/Nfollcbwcf
#
# ICYMI, yesterday the ECB proposed a new 100-ball format for their upcoming new domestic competition, and it has cer… https://t.co/ojF1PbnAFs
#
# 62 teams
# 12 regional groups
# 1 destination - World Twenty20!
#
# Presenting the full regional qualification groups for… https://t.co/zrCqIJE16t
#
# The #WT20 Asia Qualifier A has kicked off today, with hosts Kuwait, Bahrain, Maldives, Qatar, Saudi Arabia and UAE… https://t.co/K2Fao7bY0c
#
# Happy birthday to @GFoxyFowler, an England batsman who played 21 Tests and 26 ODIs, his best innings a fantastic 20… https://t.co/SKRyZHGbdA
#
# "You need to be able to deceive batsmen."
#
# Chris Woakes explains what it takes to bowl at the death.… https://t.co/EnNAFybgFk
#
# "Let bowlers know who’s in charge!"
#
# @henrygayle is riding high after another T20 💯. Watch out for him in… https://t.co/1DebrbdrCG
#
# Sri Lanka's @PereraThisara will be part of the ICC World XI taking on West Indies at Lord's in aid of hurricane rel… https://t.co/SMyn6akCbX
#
# #OnThisDay in 1994, @InziTheLegend and Aamer Sohail made a 263 run partnership for Pakistan against New Zealand in… https://t.co/Co7Bwr6DBD
#
# Ghana secured their place in the regional finals, while Nigeria squeezed home against Sierra Leone on the 4th day o… https://t.co/6i3x5KE2XB
#
# There have been 427 'one Test wonders' - which of them stand out as the most successful in their time in the spotli… https://t.co/zR8PD42PnI
#
# RT @westindies: When the Universe Boss @henrygayle found out that @SAfridiOfficial is playing for the @ICC World XI vs the WINDIES in the H…
#
# "To be playing alongside so many top players from different countries will definitely be a high point of my career.… https://t.co/JAHvATeiu2
#
# The universe boss smashes the first century of #IPL2018! Congratulations @henrygayle 👏 https://t.co/mjxDBBGVrK
#
# Following @dutchiepdb's retirement from international cricket, on #ThrowbackThursday we go back to @KNCBcricket's m… https://t.co/2C1Qj6zM3l
#
# India captain @imvKohli has re-iterated his desire to play in the @CountyChamp to prepare for the Test series again… https://t.co/XiHEjAvarz
#
# The ECB have proposed a radical new 100-balls-a-side format for their new domestic limited-overs competition due to… https://t.co/cmQzpzVKJr
#
# With @SAfridiOfficial and @realshoaibmalik announced to be part of the ICC World XI at Lord's next month, throwback… https://t.co/VQRRBUJCbe
#
# “That the match is being played at Lord’s makes this event extra special for me."
#
# @realshoaibmalik is returning to… https://t.co/HkKviO4iKc
#
# #OnThisDay in 2009, Afghanistan won their first ever ODI, beating Scotland in a 5th place play-off at the… https://t.co/v0nVX0YPZP
#
# "Any guy with half a cricket eye would have known that he was going to be a great player."
#
# @Gary_Kirsten, who is w… https://t.co/Mh2P6KQBTy
#
# “I am humbled to have been selected for such a noble cause"
#
# @SAfridiOfficial is joining the ICC World XI to face W… https://t.co/StkaQPeuEJ
#
# BREAKING: @SAfridiOfficial, @realshoaibmalik and @PereraThisara join @Eoin16 in the ICC World XI to face West Indie… https://t.co/F53UgGoEWa
#
# "Steve (Smith) was keen for the team to start playing a different style" - Tim Paine.
#
#
# Eoin Morgan keen to return to red-ball cricket. "It helps my technique. The most vulnerable part of your batting is… https://t.co/gdlqceU0oc
#
# #OnThisDay in 1992, South Africa began their first Test in 22 years against West Indies in Barbados.
#
# The hosts wo… https://t.co/nMhFFw8udB
#
# ICYMI!
#
# Windies announced their squad for their T20I charity match against an ICC World XI at the @HomeOfCricket on… https://t.co/GlANYjrPk8
#
# He's one of three Indians to have scored a century in all three international formats, and was the first Indian to… https://t.co/UZ2KVnQNsg
#
# ICYMI!
#
# Nic Pothas has stepped down as Sri Lanka's fielding consultant after almost two years in the role, which in… https://t.co/Hl1qr6u34A
#
# #OnThisDay in 2017, @henrygayle became the first player to reach 10,000 runs in Twenty20 matches!
#
# 7472 of those ca… https://t.co/085QNJj18e
#
# She has 76 international wickets for New Zealand - happy birthday to leg-spinner Erin Bermingham! https://t.co/f7ls6Gz86F
#
# Ghana claimed pole position at the #WT20 2020 Africa Qualifier A on Tuesday, beating hosts Nigeria with a ball spar… https://t.co/YekYDe3HNp
#
# West Indies' big guns are getting ready to face a star-studded ICC World XI next month in a T20I in aid of hurrican… https://t.co/YRbMflDEr0
#
# Earlier @westindies announced their squad for their match against an ICC World XI at the @HomeOfCricket in aid of c… https://t.co/OJVvsDEtSw
#
# On his birthday, watch the moment Muttiah Muralitharan​ became the first Sri Lanka​ player to be inducted in the IC… https://t.co/YIdTaskGVj
#
# Nic Pothas has stepped down from his role as Sri Lanka's fielding consultant, after almost two years in the role wh… https://t.co/Z0GpXr4WVY
#
# "We’ve slacked off in the past two years but knowing how close we were gives you that desire to get back there.”… https://t.co/TqP1TKXarl
#
# #ShotOfTheDay https://t.co/qhU4e1sg5D
#
# The PCB are planning a refurbishment of the Pindi Cricket Stadium, with approx $8.6m USD to be spent to prepare it… https://t.co/AdiQvuRLkP
#
# Jonty Rhodes called him the 'father of fielding' - Colin Bland, who played 21 Tests for South Africa between 1961 a… https://t.co/IoJKUQ4SPK
#
# West Indies have announced their squad for their T20I charity match against an ICC World XI at the @HomeOfCricket o… https://t.co/funJf51gtC
#
# RT @Gibraltar_Crick: What a glorious day of Cricket down at the Victoria Stadium for our Inter School Festival! No better backdrop that the…
#
# Suzie Bates thrilled to be compared to Debbie Hockley, as the White Ferns captain approaches her record for the mos… https://t.co/rZ97mooeDd
#
# #OnTheUp: There was #IPL2018 excitement, #CountyCricket enticement and a lot of non-cricketing enjoyment!
#
# Here's w… https://t.co/ZJFm2U3ZGL
#
# “I went up to Faf and said, ‘Listen, is this international Test match cricket?’"
#
# For @AidzMarkram, the #SAvAUS se… https://t.co/K5zvAwAp4y
#
# 800 Test wickets.
# 534 ODI wickets.
# The most prolific bowler in international cricket history.
#
# Happy birthday to S… https://t.co/5oWzS4Slwd
#
# The lenght's average in tweets: 135.22
# The tweet with more likes is:
# 💕 @msdhoni 😍
#
# #CSKvRR #IPL2018 https://t.co/j2t5Scuwzs
# Number of likes: 13932
# 54 characters.
#
# The tweet with more retweets is:
# The moment Pakistan got one hand on the ICC Champions Trophy! 🏆
#
# To celebrate @iamamirofficial's birthday, revisit… https://t.co/9mijX8L55r
# Number of retweets: 2108
# 139 characters.
#
# Creation of content sources:
# * TweetDeck
# * Media Studio
# * Twitter Web Client
# * Twitter for Android
#                                                Tweets  len  \
# 0   India captain @M_Raj03 on the rapid developmen...  134
# 1   Happy birthday to Nepal's Shakti Gauchan!\n\nW...  133
# 2   “KL looked like a million dollars, and well, C...  139
# 3   6,792 international runs\nJoint fastest to 1,0...  140
# 4   "The team is inexperienced, but we are trying ...  140
# 5   RT @ICCAcademy: The #ICCAcademy welcomed @Cric...  139
# 6   Happy 52nd birthday to ICC Elite Umpire Sundar...   78
# 7   AB IS BACK!\n\n"Some of the nights you see the...  139
# 8   Happy birthday to Ranjan Madugalle! \n\nThe to...  140
# 9   He took Nepal's first ever international hat-t...  140
# 10  Happy 19th birthday to New Zealand U19s star F...  140
# 11  Ghana beat Nigeria to finish top of the table ...  131
# 12  Her ability to put it on a postage stamp time ...  140
# 13  Pakistan have picked five uncapped players in ...  125
# 14  “The kind of ODI team we have, we are favourit...  140
# 15  ICYMI: "The Netherlands have got a fantastic b...  140
# 16  What a #countychampionship debut for @MattRens...  140
# 17  "If it’s improving the standard of the county ...  140
# 18  A team-mate, a Pakistan legend, a South Africa...  140
# 19  In their quest for #WT20 2020, Kuwait, UAE and...  140
# 20  Happy birthday to the Sri Lanka Test opener wh...  140
# 21  He took 157 Test wickets for India, captained ...  140
# 22  Outgoing Netherlands captain @dutchiepdb has g...  140
# 23  ICYMI, @virendersehwag 'saved the IPL' by pick...  115
# 24  “Playing county cricket will help me improve m...  139
# 25  💕 @msdhoni 😍\n\n#CSKvRR #IPL2018 https://t.co/...   54
# 26  He has two centuries for @rajasthanroyals - no...  140
# 27  Boom boom! 💥 @SAfridiOfficial is part of the I...  139
# 28  A rare sight - sizzling sun for early season @...  104
# 29  The ECB have appointed @edsmithwriter as their...  140
# ..                                                ...  ...
# 70  Nepal's @paras77 - inspiring the next generati...  136
# 71                          🙋 https://t.co/n2HzcY1Smx   25
# 72  One of the finest pace bowlers of all time, he...  133
# 73  Congratulations to @Kathryn_Bryce who has been...  132
# 74  England opener @mark23stone is keen to pick th...  140
# 75  766 minutes\n538 balls\n45 fours\n375 runs!\n\...  139
# 76  Cricket Australia have dismissed speculation t...  140
# 77  RCB coach Trent Woodhill has hailed @ABdeVilli...  140
# 78  Eoin Morgan keen to return to red-ball cricket...  140
# 79  #OnThisDay in 1992, South Africa began their f...  140
# 80  ICYMI!\n\nWindies announced their squad for th...  140
# 81  He's one of three Indians to have scored a cen...  139
# 82  ICYMI!\n\nNic Pothas has stepped down as Sri L...  140
# 83  #OnThisDay in 2017, @henrygayle became the fir...  140
# 84  She has 76 international wickets for New Zeala...  121
# 85  Ghana claimed pole position at the #WT20 2020 ...  140
# 86  West Indies' big guns are getting ready to fac...  140
